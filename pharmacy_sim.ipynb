# %% [markdown]
# # Farmacy Simulation with SimPy
# ## Scenario
# A pharmacy has `NR_COUNTERS` counters with a working pharmacist each.
#
# The Pharmacy has `NR_MEDS` types of medicine, each having a `stock` of `MED_STOCK` units.
#
# Customers arrive randomly using an *Exponential Distribution*.
#
# Customers are served at the counter for a certain duration using the *Lognormal Distribution*.
#
# While waiting in a queue, each customer has a `patience`, modelled using a *Weibull Distribution*.
#
# Customers choose a medicine type randomly when arriving at the pharmacy.

# %% [markdown]
# ### Math Reminder I - Exponential Distribution
# The **Exponential Distribution** is the distribution of the distance between events in a **Poisson point process**, i.e. a process in which events occur continuously and independently at a constant average rate.
#
# The *Probability Density Function* of the **Exponential Distribution** is as follows:
#
# $$
# f(x;\lambda) = \lambda e^{-\lambda x} \quad \text{for} \quad x \geq 0
# $$
# and $0$ otherwise.

# %% [markdown]
# $\lambda$ is the *rate* parameter of our distribution. It controls *how often* an event may happen.
#
# In our case, if a customer arrives at a pharmacy every $t$ minutes on average, then $\lambda = 1/t$

# %% [markdown]
# ### Math Reminder II - Lognormal Distribution
# The **Lognormal Distribution** is the distribution of a random variable whose *logarithm* is normally distributed. Thus, if $X$ is a normally distributed r.v., then $Y = e^X$ has a lognormal distribution.
#
# The *Probability Density Function* of the **Lognormal Distribution** is as follows:
# $$
# f(x;\mu, \sigma) = \frac{1}{x\sigma \sqrt{2\pi}} \exp{(-\frac{(\ln x - \mu)^2}{2\sigma^2})}
# $$

# %% [markdown]
# > ⚠️ **Caution:** A very important thing to know is that $\mu$ and $\sigma$ are **NOT** the mean and std of the service time we want to model. These are the mean and standard deviation of the *logarithm* of service time.

# %% [markdown]
# ### Math Reminder III - Weibull Distribution
# The **Weibull Distribution** can model a broad range of random variables. It is often used to model time to failure (of a machine, for example), time between events, or the time a person spends on a website. I chose to use it to model a customer's patience while standing in the pharmacy's queue.
#
# The *Probability Density Function* of the **Weibull Distribution** is as follows:
# $$
# f(x; \lambda, k) = \frac{k}{\lambda}* (\frac{x}{\lambda})^{k-1} * e^{-(x/\lambda)^k} \quad \text{for} \quad x \geq 0
# $$
# and $0$ otherwise.

# %% [markdown]
# The two parameters, $k$ and $\lambda$, are **always** greater than $0$.
#
# - $k$ is the **shape** parameter. It controls the *qualitative* behavior of the distribution.
# - $\lambda$ is the **scale** parameter. It changes the *horizontal stretch* of the distribution. Greater $\lambda$ will stretch the curve to the right, while a lesser value will compress the pdf.
#
# When $k < 1$:</br>
# The curve becomes very steep near 0 and decays quickly. </br>
# In our example, this would mean customers will lose patience almost immediately.
#
# When $k = 1$:</br>
# The **Weibull** Distribution becomes an **Exponential** Distribution.
#
# When $k > 1$:</br>
# The curve rises, peaks, then falls. The bigger the $k$, the sharper the rise and the more peaked the pdf is.

# %%
import random
import simpy
import numpy as np
import matplotlib.pyplot as plt
from math import log
from typing import Dict, List, Optional, NamedTuple

# %%
SEED = 42
LAMBDA_EXP = 1.5        # customer arrival rate for exponential distribution
MU_LOGNORM = 0.6        # mean for lognormal distribution
SIGMA_LOGNORM = 0.3     # std for lognormal distribution
SHAPE_WEIBULL = 8         # shape param for Weibull distribution
SCALE_WEIBULL = 7.5     # scale param for Weibull distribution
MED_STOCK = 200          # number of boxes per medicine
NR_COUNTERS = 3         # number of pharmacy cashiers / counters
NR_MED_TYPES = 3        # number of medicine types

SIM_HOURS = 12          # simulation time in hours
SIM_TIME = SIM_HOURS * 60      # total simulation time in minutes

# %%
def expovar(x):
    if x < 0:
        return 0
    else:
        return LAMBDA_EXP * np.exp(-LAMBDA_EXP * x)
    
expovar = np.vectorize(expovar)

def lognormal(x):
    return (1/(x * SIGMA_LOGNORM * np.sqrt(2 * np.pi))) * np.exp(-(log(x) - MU_LOGNORM)**2 / (2 * SIGMA_LOGNORM**2))

lognormal = np.vectorize(lognormal)

def weibull(x):
    if x < 0:
        return 0
    else:
        return (SHAPE_WEIBULL / SCALE_WEIBULL) * (x / SCALE_WEIBULL)**(SHAPE_WEIBULL-1) * np.exp(-(x/SCALE_WEIBULL)**SHAPE_WEIBULL)

weibull = np.vectorize(weibull)

xs = np.linspace(0.001, 10, 500)
ys1 = expovar(xs)
ys2 = lognormal(xs)
ys3 = weibull(xs)

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(1, 1, 1)
bigticks = np.arange(-1, 11, 0.5)
smallticks = np.arange(-1, 11, 0.1)
ax.set_xticks(bigticks)
ax.set_xticks(smallticks, minor=True)
ax.set_yticks(bigticks)
ax.set_yticks(smallticks, minor=True)
ax.grid(which="minor", alpha=0.3, c="gray")
ax.grid(which="major", alpha=0.4, c="black")

ax.axhline(c="black", linewidth=2.5)
ax.axvline(c="black", linewidth=2.5)

plt.plot(xs, ys1, c="red", label=f"Exponential | lambda = {LAMBDA_EXP}")
plt.plot(xs, ys2, c="green", label=f"Lognormal | mu = {MU_LOGNORM}, sigma = {SIGMA_LOGNORM}")
plt.plot(xs, ys3, c="blue", label=f"Weibull | k = {SHAPE_WEIBULL}, lambda = {SCALE_WEIBULL}")

plt.title("R.V. distributions used in this simulation")
plt.legend()
plt.show()

# %%
class Stats(NamedTuple):
    q_wait_times: List[float]
    s_wait_times: List[float]

stats = Stats(
    q_wait_times = [],
    s_wait_times = []
)

nr_impatient_leavers = 0

# %%
def customer(env, name, medicine, pharmacy):
    """A customer tries to buy a *medicine* from the *pharmacy*.
    
    
    If the medicine is sold out, the customer leaves the pharmacy immediately.
    Otherwise, if they reach the counter they are served for an amount of time and then leave.
    If they stay in the queue for too long, the customer will eventually leave."""

    print(f"{env.now:.2f}: {name} arrived at the pharmacy.")
    arrival_time = env.now

    with pharmacy.counters.request() as my_turn: # request counter resource
        patience = random.weibullvariate(SCALE_WEIBULL, SHAPE_WEIBULL)
        result = yield my_turn | env.timeout(patience) | pharmacy.sold_out[medicine] # check if it's customer's turn or the medicine is sold out

        queue_wait_time = env.now - arrival_time

        if my_turn not in result: # the medicine is sold out, the customer leaves
            if pharmacy.sold_out[medicine] in result:
                print(f"{env.now:.2f}: {name} left because {medicine} is sold out. Queue wait time: {queue_wait_time:.2f} minutes.")
                pharmacy.num_renegers[medicine] += 1
                return
            else:
                print(f"{env.now:.2f}: {name} left after their patience ran out. Queue wait time: {queue_wait_time:.2f} minutes.")
                global nr_impatient_leavers
                nr_impatient_leavers += 1
                return

        pharmacy.med_stock[medicine] -= 1 # the customer buys the medicine
        counter_access_time = env.now
        print(f"{env.now:.2f}: {name} reserved 1 unit of {medicine} after reaching the counter. Queue waiting time: {queue_wait_time:.2f} minutes.")
        stats.q_wait_times.append(queue_wait_time)

        if pharmacy.med_stock[medicine] < 1:
            print(f"{env.now:.2f}: LAST unit of {medicine} reserved by {name}. No more can be reserved!")
            pharmacy.sold_out_timestamp[medicine] = env.now
            pharmacy.sold_out[medicine].succeed()
            pharmacy.med_stock[medicine] = 0

        yield env.timeout(np.random.lognormal(MU_LOGNORM, SIGMA_LOGNORM))
        
        service_time = env.now - counter_access_time
        stats.s_wait_times.append(service_time)
        total_wait_time = queue_wait_time + service_time
        print(f"{env.now:.2f}: {name} received {medicine} and left. Queue wait time: {queue_wait_time:.2f} minutes. Service time: {service_time:.2f} minutes. Total time spent at pharmacy: {total_wait_time:.2f}.")

# %%
def generate_customers(env, pharmacy):
    """Generate new *customers* until simulation ends."""

    i = 1
    while True:
        yield env.timeout(random.expovariate(LAMBDA_EXP))

        medicine = random.choice(pharmacy.medicines)
        if pharmacy.med_stock[medicine] >= 1: # check if the medicine the customer wants is in stock before spawning a process
            env.process(customer(env, f"Customer#{i}", medicine, pharmacy))
            i += 1

# %%
class Pharmacy(NamedTuple):
    counters: simpy.Resource
    medicines: List[str]
    med_stock: Dict[str, int]
    sold_out: Dict[str, simpy.Event]
    num_renegers: Dict[str, int]
    sold_out_timestamp: Dict[str, Optional[float]]

# %%
random.seed(SEED)
np.random.seed(SEED)
env = simpy.Environment()
medicines = [f"Medicine#{i}" for i in range(1, NR_MED_TYPES+1)]
pharmacy = Pharmacy(
    counters = simpy.Resource(env, capacity=NR_COUNTERS),
    medicines = medicines,
    med_stock = {medicine: MED_STOCK for medicine in medicines},
    sold_out = {medicine: env.event() for medicine in medicines},
    sold_out_timestamp = {medicine: None for medicine in medicines},
    num_renegers = {medicine: 0 for medicine in  medicines}
)

env.process(generate_customers(env, pharmacy))
# Out:
# <Process(generate_customers) object at 0x7fe1901e7750>

# %%
env.run(until=SIM_TIME)
# Out:
# 0.68: Customer#1 arrived at the pharmacy.
# 0.68: Customer#1 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 1.58: Customer#2 arrived at the pharmacy.
# 1.58: Customer#2 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 2.47: Customer#3 arrived at the pharmacy.
# 2.47: Customer#3 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.00 minutes.
# 2.53: Customer#4 arrived at the pharmacy.
# 2.60: Customer#5 arrived at the pharmacy.
# 2.62: Customer#6 arrived at the pharmacy.
# 2.79: Customer#1 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 2.11 minutes. Total time spent at pharmacy: 2.11.
# 2.79: Customer#4 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.26 minutes.
# 3.33: Customer#2 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.75 minutes. Total time spent at pharmacy: 1.75.
# 3.33: Customer#5 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.73 minutes.
# 3.42: Customer#7 arrived at the pharmacy.
# 4.01: Customer#8 arrived at the pharmacy.
# 4.68: Customer#3 received Medicine#3 and left. Queue wait time: 0.00 minutes. Service time: 2.21 minutes. Total time spent at pharmacy: 2.21.
# 4.68: Customer#6 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 2.07 minutes.
# 4.96: Customer#9 arrived at the pharmacy.
# 5.03: Customer#5 received Medicine#3 and left. Queue wait time: 0.73 minutes. Service time: 1.70 minutes. Total time spent at pharmacy: 2.43.
# 5.03: Customer#7 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 1.61 minutes.
# 5.24: Customer#10 arrived at the pharmacy.
# 5.31: Customer#11 arrived at the pharmacy.
# 5.67: Customer#4 received Medicine#1 and left. Queue wait time: 0.26 minutes. Service time: 2.88 minutes. Total time spent at pharmacy: 3.14.
# 5.67: Customer#8 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 1.66 minutes.
# 6.38: Customer#6 received Medicine#3 and left. Queue wait time: 2.07 minutes. Service time: 1.70 minutes. Total time spent at pharmacy: 3.77.
# 6.38: Customer#9 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 1.42 minutes.
# 6.57: Customer#12 arrived at the pharmacy.
# 7.44: Customer#13 arrived at the pharmacy.
# 7.49: Customer#14 arrived at the pharmacy.
# 7.96: Customer#7 received Medicine#2 and left. Queue wait time: 1.61 minutes. Service time: 2.93 minutes. Total time spent at pharmacy: 4.53.
# 7.96: Customer#10 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.72 minutes.
# 7.97: Customer#9 received Medicine#2 and left. Queue wait time: 1.42 minutes. Service time: 1.58 minutes. Total time spent at pharmacy: 3.00.
# 7.97: Customer#11 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.65 minutes.
# 7.97: Customer#8 received Medicine#1 and left. Queue wait time: 1.66 minutes. Service time: 2.29 minutes. Total time spent at pharmacy: 3.95.
# 7.97: Customer#12 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 1.40 minutes.
# 8.13: Customer#15 arrived at the pharmacy.
# 8.28: Customer#16 arrived at the pharmacy.
# 8.45: Customer#17 arrived at the pharmacy.
# 9.55: Customer#12 received Medicine#1 and left. Queue wait time: 1.40 minutes. Service time: 1.58 minutes. Total time spent at pharmacy: 2.99.
# 9.55: Customer#13 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.11 minutes.
# 9.55: Customer#11 received Medicine#2 and left. Queue wait time: 2.65 minutes. Service time: 1.59 minutes. Total time spent at pharmacy: 4.24.
# 9.55: Customer#14 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 2.06 minutes.
# 9.74: Customer#18 arrived at the pharmacy.
# 9.96: Customer#19 arrived at the pharmacy.
# 10.07: Customer#20 arrived at the pharmacy.
# 10.10: Customer#10 received Medicine#2 and left. Queue wait time: 2.72 minutes. Service time: 2.14 minutes. Total time spent at pharmacy: 4.86.
# 10.10: Customer#15 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 1.96 minutes.
# 10.28: Customer#21 arrived at the pharmacy.
# 10.33: Customer#22 arrived at the pharmacy.
# 10.58: Customer#14 received Medicine#3 and left. Queue wait time: 2.06 minutes. Service time: 1.03 minutes. Total time spent at pharmacy: 3.09.
# 10.58: Customer#16 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 2.30 minutes.
# 11.19: Customer#15 received Medicine#3 and left. Queue wait time: 1.96 minutes. Service time: 1.09 minutes. Total time spent at pharmacy: 3.05.
# 11.19: Customer#17 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 2.74 minutes.
# 11.20: Customer#23 arrived at the pharmacy.
# 11.41: Customer#24 arrived at the pharmacy.
# 11.51: Customer#13 received Medicine#2 and left. Queue wait time: 2.11 minutes. Service time: 1.96 minutes. Total time spent at pharmacy: 4.07.
# 11.51: Customer#18 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 1.77 minutes.
# 11.95: Customer#25 arrived at the pharmacy.
# 12.12: Customer#16 received Medicine#3 and left. Queue wait time: 2.30 minutes. Service time: 1.54 minutes. Total time spent at pharmacy: 3.84.
# 12.12: Customer#19 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.16 minutes.
# 12.13: Customer#26 arrived at the pharmacy.
# 12.47: Customer#27 arrived at the pharmacy.
# 12.53: Customer#17 received Medicine#1 and left. Queue wait time: 2.74 minutes. Service time: 1.34 minutes. Total time spent at pharmacy: 4.08.
# 12.53: Customer#20 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 2.46 minutes.
# 13.50: Customer#19 received Medicine#2 and left. Queue wait time: 2.16 minutes. Service time: 1.39 minutes. Total time spent at pharmacy: 3.55.
# 13.50: Customer#21 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 3.22 minutes.
# 13.51: Customer#18 received Medicine#2 and left. Queue wait time: 1.77 minutes. Service time: 2.00 minutes. Total time spent at pharmacy: 3.77.
# 13.51: Customer#22 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 3.18 minutes.
# 13.72: Customer#20 received Medicine#3 and left. Queue wait time: 2.46 minutes. Service time: 1.19 minutes. Total time spent at pharmacy: 3.65.
# 13.72: Customer#23 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.52 minutes.
# 13.86: Customer#28 arrived at the pharmacy.
# 14.32: Customer#29 arrived at the pharmacy.
# 14.73: Customer#30 arrived at the pharmacy.
# 15.22: Customer#22 received Medicine#3 and left. Queue wait time: 3.18 minutes. Service time: 1.70 minutes. Total time spent at pharmacy: 4.89.
# 15.22: Customer#24 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 3.80 minutes.
# 15.58: Customer#23 received Medicine#2 and left. Queue wait time: 2.52 minutes. Service time: 1.86 minutes. Total time spent at pharmacy: 4.38.
# 15.58: Customer#25 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 3.63 minutes.
# 15.64: Customer#31 arrived at the pharmacy.
# 16.23: Customer#32 arrived at the pharmacy.
# 16.33: Customer#21 received Medicine#3 and left. Queue wait time: 3.22 minutes. Service time: 2.83 minutes. Total time spent at pharmacy: 6.05.
# 16.33: Customer#26 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 4.21 minutes.
# 16.40: Customer#24 received Medicine#3 and left. Queue wait time: 3.80 minutes. Service time: 1.19 minutes. Total time spent at pharmacy: 4.99.
# 16.40: Customer#27 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 3.94 minutes.
# 16.53: Customer#33 arrived at the pharmacy.
# 17.00: Customer#34 arrived at the pharmacy.
# 17.13: Customer#25 received Medicine#1 and left. Queue wait time: 3.63 minutes. Service time: 1.55 minutes. Total time spent at pharmacy: 5.18.
# 17.13: Customer#28 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 3.27 minutes.
# 17.69: Customer#27 received Medicine#3 and left. Queue wait time: 3.94 minutes. Service time: 1.29 minutes. Total time spent at pharmacy: 5.23.
# 17.69: Customer#29 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 3.37 minutes.
# 18.22: Customer#26 received Medicine#2 and left. Queue wait time: 4.21 minutes. Service time: 1.88 minutes. Total time spent at pharmacy: 6.09.
# 18.22: Customer#30 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 3.48 minutes.
# 18.32: Customer#35 arrived at the pharmacy.
# 19.17: Customer#28 received Medicine#3 and left. Queue wait time: 3.27 minutes. Service time: 2.04 minutes. Total time spent at pharmacy: 5.31.
# 19.17: Customer#31 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 3.53 minutes.
# 19.22: Customer#29 received Medicine#3 and left. Queue wait time: 3.37 minutes. Service time: 1.52 minutes. Total time spent at pharmacy: 4.89.
# 19.22: Customer#32 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.99 minutes.
# 19.37: Customer#36 arrived at the pharmacy.
# 19.69: Customer#37 arrived at the pharmacy.
# 19.89: Customer#30 received Medicine#1 and left. Queue wait time: 3.48 minutes. Service time: 1.67 minutes. Total time spent at pharmacy: 5.15.
# 19.89: Customer#33 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 3.36 minutes.
# 20.19: Customer#38 arrived at the pharmacy.
# 20.69: Customer#31 received Medicine#3 and left. Queue wait time: 3.53 minutes. Service time: 1.52 minutes. Total time spent at pharmacy: 5.05.
# 20.69: Customer#34 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 3.69 minutes.
# 20.95: Customer#39 arrived at the pharmacy.
# 21.70: Customer#33 received Medicine#1 and left. Queue wait time: 3.36 minutes. Service time: 1.81 minutes. Total time spent at pharmacy: 5.17.
# 21.70: Customer#35 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 3.38 minutes.
# 21.88: Customer#40 arrived at the pharmacy.
# 21.96: Customer#41 arrived at the pharmacy.
# 21.96: Customer#42 arrived at the pharmacy.
# 22.02: Customer#34 received Medicine#1 and left. Queue wait time: 3.69 minutes. Service time: 1.33 minutes. Total time spent at pharmacy: 5.01.
# 22.02: Customer#36 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 2.65 minutes.
# 22.16: Customer#43 arrived at the pharmacy.
# 22.39: Customer#32 received Medicine#2 and left. Queue wait time: 2.99 minutes. Service time: 3.18 minutes. Total time spent at pharmacy: 6.16.
# 22.39: Customer#37 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.70 minutes.
# 22.64: Customer#44 arrived at the pharmacy.
# 22.87: Customer#45 arrived at the pharmacy.
# 23.02: Customer#46 arrived at the pharmacy.
# 23.28: Customer#36 received Medicine#1 and left. Queue wait time: 2.65 minutes. Service time: 1.26 minutes. Total time spent at pharmacy: 3.91.
# 23.28: Customer#38 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 3.09 minutes.
# 23.54: Customer#47 arrived at the pharmacy.
# 24.03: Customer#35 received Medicine#1 and left. Queue wait time: 3.38 minutes. Service time: 2.33 minutes. Total time spent at pharmacy: 5.71.
# 24.03: Customer#39 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 3.08 minutes.
# 24.29: Customer#38 received Medicine#1 and left. Queue wait time: 3.09 minutes. Service time: 1.01 minutes. Total time spent at pharmacy: 4.10.
# 24.29: Customer#40 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.41 minutes.
# 24.33: Customer#37 received Medicine#2 and left. Queue wait time: 2.70 minutes. Service time: 1.94 minutes. Total time spent at pharmacy: 4.64.
# 24.33: Customer#41 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.37 minutes.
# 25.21: Customer#48 arrived at the pharmacy.
# 25.22: Customer#49 arrived at the pharmacy.
# 25.26: Customer#39 received Medicine#3 and left. Queue wait time: 3.08 minutes. Service time: 1.22 minutes. Total time spent at pharmacy: 4.30.
# 25.26: Customer#42 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 3.30 minutes.
# 25.40: Customer#50 arrived at the pharmacy.
# 26.23: Customer#40 received Medicine#2 and left. Queue wait time: 2.41 minutes. Service time: 1.93 minutes. Total time spent at pharmacy: 4.35.
# 26.23: Customer#43 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 4.06 minutes.
# 26.61: Customer#41 received Medicine#2 and left. Queue wait time: 2.37 minutes. Service time: 2.27 minutes. Total time spent at pharmacy: 4.65.
# 26.61: Customer#44 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 3.97 minutes.
# 27.17: Customer#42 received Medicine#3 and left. Queue wait time: 3.30 minutes. Service time: 1.92 minutes. Total time spent at pharmacy: 5.21.
# 27.17: Customer#45 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 4.30 minutes.
# 27.36: Customer#51 arrived at the pharmacy.
# 27.99: Customer#43 received Medicine#1 and left. Queue wait time: 4.06 minutes. Service time: 1.76 minutes. Total time spent at pharmacy: 5.82.
# 27.99: Customer#46 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 4.96 minutes.
# 28.27: Customer#44 received Medicine#3 and left. Queue wait time: 3.97 minutes. Service time: 1.66 minutes. Total time spent at pharmacy: 5.63.
# 28.27: Customer#47 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 4.73 minutes.
# 28.34: Customer#45 received Medicine#3 and left. Queue wait time: 4.30 minutes. Service time: 1.17 minutes. Total time spent at pharmacy: 5.47.
# 28.34: Customer#48 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 3.13 minutes.
# 28.49: Customer#52 arrived at the pharmacy.
# 29.45: Customer#46 received Medicine#1 and left. Queue wait time: 4.96 minutes. Service time: 1.47 minutes. Total time spent at pharmacy: 6.43.
# 29.45: Customer#49 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 4.23 minutes.
# 29.46: Customer#53 arrived at the pharmacy.
# 29.86: Customer#47 received Medicine#3 and left. Queue wait time: 4.73 minutes. Service time: 1.59 minutes. Total time spent at pharmacy: 6.32.
# 29.86: Customer#50 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 4.45 minutes.
# 30.85: Customer#48 received Medicine#2 and left. Queue wait time: 3.13 minutes. Service time: 2.50 minutes. Total time spent at pharmacy: 5.64.
# 30.85: Customer#51 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 3.48 minutes.
# 30.93: Customer#50 received Medicine#3 and left. Queue wait time: 4.45 minutes. Service time: 1.07 minutes. Total time spent at pharmacy: 5.53.
# 30.93: Customer#52 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 2.44 minutes.
# 31.42: Customer#54 arrived at the pharmacy.
# 31.47: Customer#49 received Medicine#2 and left. Queue wait time: 4.23 minutes. Service time: 2.02 minutes. Total time spent at pharmacy: 6.25.
# 31.47: Customer#53 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.02 minutes.
# 32.55: Customer#52 received Medicine#3 and left. Queue wait time: 2.44 minutes. Service time: 1.62 minutes. Total time spent at pharmacy: 4.06.
# 32.55: Customer#54 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 1.14 minutes.
# 32.79: Customer#55 arrived at the pharmacy.
# 32.85: Customer#51 received Medicine#2 and left. Queue wait time: 3.48 minutes. Service time: 2.01 minutes. Total time spent at pharmacy: 5.49.
# 32.85: Customer#55 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.07 minutes.
# 32.96: Customer#53 received Medicine#2 and left. Queue wait time: 2.02 minutes. Service time: 1.49 minutes. Total time spent at pharmacy: 3.50.
# 34.55: Customer#56 arrived at the pharmacy.
# 34.55: Customer#56 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.00 minutes.
# 34.70: Customer#57 arrived at the pharmacy.
# 34.74: Customer#54 received Medicine#3 and left. Queue wait time: 1.14 minutes. Service time: 2.19 minutes. Total time spent at pharmacy: 3.33.
# 34.74: Customer#57 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.04 minutes.
# 35.34: Customer#55 received Medicine#1 and left. Queue wait time: 0.07 minutes. Service time: 2.48 minutes. Total time spent at pharmacy: 2.55.
# 35.40: Customer#58 arrived at the pharmacy.
# 35.40: Customer#58 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.00 minutes.
# 35.80: Customer#59 arrived at the pharmacy.
# 36.08: Customer#60 arrived at the pharmacy.
# 36.16: Customer#57 received Medicine#3 and left. Queue wait time: 0.04 minutes. Service time: 1.42 minutes. Total time spent at pharmacy: 1.46.
# 36.16: Customer#59 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.36 minutes.
# 36.67: Customer#61 arrived at the pharmacy.
# 36.96: Customer#56 received Medicine#3 and left. Queue wait time: 0.00 minutes. Service time: 2.41 minutes. Total time spent at pharmacy: 2.41.
# 36.96: Customer#60 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.88 minutes.
# 37.06: Customer#58 received Medicine#3 and left. Queue wait time: 0.00 minutes. Service time: 1.66 minutes. Total time spent at pharmacy: 1.66.
# 37.06: Customer#61 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.39 minutes.
# 37.33: Customer#62 arrived at the pharmacy.
# 38.17: Customer#59 received Medicine#1 and left. Queue wait time: 0.36 minutes. Service time: 2.01 minutes. Total time spent at pharmacy: 2.37.
# 38.17: Customer#62 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.84 minutes.
# 38.64: Customer#61 received Medicine#3 and left. Queue wait time: 0.39 minutes. Service time: 1.58 minutes. Total time spent at pharmacy: 1.97.
# 38.64: Customer#63 arrived at the pharmacy.
# 38.64: Customer#63 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 38.86: Customer#64 arrived at the pharmacy.
# 38.95: Customer#65 arrived at the pharmacy.
# 39.40: Customer#60 received Medicine#1 and left. Queue wait time: 0.88 minutes. Service time: 2.44 minutes. Total time spent at pharmacy: 3.33.
# 39.40: Customer#64 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.54 minutes.
# 39.53: Customer#66 arrived at the pharmacy.
# 39.90: Customer#62 received Medicine#1 and left. Queue wait time: 0.84 minutes. Service time: 1.72 minutes. Total time spent at pharmacy: 2.56.
# 39.90: Customer#65 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.94 minutes.
# 39.95: Customer#63 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.31 minutes. Total time spent at pharmacy: 1.31.
# 39.95: Customer#66 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 0.42 minutes.
# 40.62: Customer#67 arrived at the pharmacy.
# 40.67: Customer#64 received Medicine#3 and left. Queue wait time: 0.54 minutes. Service time: 1.27 minutes. Total time spent at pharmacy: 1.82.
# 40.67: Customer#67 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.05 minutes.
# 41.34: Customer#68 arrived at the pharmacy.
# 41.76: Customer#69 arrived at the pharmacy.
# 42.22: Customer#65 received Medicine#3 and left. Queue wait time: 0.94 minutes. Service time: 2.33 minutes. Total time spent at pharmacy: 3.27.
# 42.22: Customer#68 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 0.88 minutes.
# 42.46: Customer#67 received Medicine#1 and left. Queue wait time: 0.05 minutes. Service time: 1.78 minutes. Total time spent at pharmacy: 1.83.
# 42.46: Customer#69 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.70 minutes.
# 42.47: Customer#70 arrived at the pharmacy.
# 42.69: Customer#66 received Medicine#2 and left. Queue wait time: 0.42 minutes. Service time: 2.74 minutes. Total time spent at pharmacy: 3.16.
# 42.69: Customer#70 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.22 minutes.
# 42.81: Customer#71 arrived at the pharmacy.
# 43.00: Customer#72 arrived at the pharmacy.
# 43.10: Customer#73 arrived at the pharmacy.
# 43.29: Customer#74 arrived at the pharmacy.
# 44.19: Customer#70 received Medicine#1 and left. Queue wait time: 0.22 minutes. Service time: 1.50 minutes. Total time spent at pharmacy: 1.72.
# 44.19: Customer#71 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 1.38 minutes.
# 44.39: Customer#75 arrived at the pharmacy.
# 44.43: Customer#76 arrived at the pharmacy.
# 44.49: Customer#69 received Medicine#3 and left. Queue wait time: 0.70 minutes. Service time: 2.03 minutes. Total time spent at pharmacy: 2.73.
# 44.49: Customer#72 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 1.49 minutes.
# 44.68: Customer#68 received Medicine#2 and left. Queue wait time: 0.88 minutes. Service time: 2.46 minutes. Total time spent at pharmacy: 3.34.
# 44.68: Customer#73 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 1.58 minutes.
# 46.22: Customer#71 received Medicine#1 and left. Queue wait time: 1.38 minutes. Service time: 2.03 minutes. Total time spent at pharmacy: 3.41.
# 46.22: Customer#74 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.92 minutes.
# 46.49: Customer#73 received Medicine#2 and left. Queue wait time: 1.58 minutes. Service time: 1.80 minutes. Total time spent at pharmacy: 3.38.
# 46.49: Customer#75 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 2.09 minutes.
# 46.74: Customer#77 arrived at the pharmacy.
# 46.87: Customer#78 arrived at the pharmacy.
# 47.32: Customer#75 received Medicine#1 and left. Queue wait time: 2.09 minutes. Service time: 0.83 minutes. Total time spent at pharmacy: 2.92.
# 47.32: Customer#76 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 2.89 minutes.
# 47.38: Customer#72 received Medicine#2 and left. Queue wait time: 1.49 minutes. Service time: 2.89 minutes. Total time spent at pharmacy: 4.38.
# 47.38: Customer#77 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.63 minutes.
# 48.20: Customer#79 arrived at the pharmacy.
# 48.52: Customer#80 arrived at the pharmacy.
# 49.13: Customer#74 received Medicine#2 and left. Queue wait time: 2.92 minutes. Service time: 2.91 minutes. Total time spent at pharmacy: 5.84.
# 49.13: Customer#78 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 2.27 minutes.
# 49.25: Customer#77 received Medicine#1 and left. Queue wait time: 0.63 minutes. Service time: 1.87 minutes. Total time spent at pharmacy: 2.50.
# 49.25: Customer#79 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 1.05 minutes.
# 49.65: Customer#76 received Medicine#1 and left. Queue wait time: 2.89 minutes. Service time: 2.33 minutes. Total time spent at pharmacy: 5.22.
# 49.65: Customer#80 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 1.13 minutes.
# 50.26: Customer#81 arrived at the pharmacy.
# 50.62: Customer#82 arrived at the pharmacy.
# 50.65: Customer#80 received Medicine#2 and left. Queue wait time: 1.13 minutes. Service time: 1.00 minutes. Total time spent at pharmacy: 2.14.
# 50.65: Customer#81 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 0.39 minutes.
# 50.80: Customer#78 received Medicine#1 and left. Queue wait time: 2.27 minutes. Service time: 1.67 minutes. Total time spent at pharmacy: 3.93.
# 50.80: Customer#82 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.17 minutes.
# 51.12: Customer#79 received Medicine#1 and left. Queue wait time: 1.05 minutes. Service time: 1.87 minutes. Total time spent at pharmacy: 2.92.
# 51.35: Customer#83 arrived at the pharmacy.
# 51.35: Customer#83 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 51.58: Customer#84 arrived at the pharmacy.
# 52.36: Customer#81 received Medicine#2 and left. Queue wait time: 0.39 minutes. Service time: 1.71 minutes. Total time spent at pharmacy: 2.10.
# 52.36: Customer#84 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.78 minutes.
# 52.47: Customer#85 arrived at the pharmacy.
# 52.51: Customer#86 arrived at the pharmacy.
# 52.83: Customer#82 received Medicine#3 and left. Queue wait time: 0.17 minutes. Service time: 2.03 minutes. Total time spent at pharmacy: 2.20.
# 52.83: Customer#85 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 0.36 minutes.
# 53.92: Customer#84 received Medicine#3 and left. Queue wait time: 0.78 minutes. Service time: 1.56 minutes. Total time spent at pharmacy: 2.34.
# 53.92: Customer#86 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 1.41 minutes.
# 54.19: Customer#83 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 2.84 minutes. Total time spent at pharmacy: 2.84.
# 54.19: Customer#87 arrived at the pharmacy.
# 54.19: Customer#87 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 54.25: Customer#85 received Medicine#2 and left. Queue wait time: 0.36 minutes. Service time: 1.43 minutes. Total time spent at pharmacy: 1.79.
# 55.48: Customer#86 received Medicine#3 and left. Queue wait time: 1.41 minutes. Service time: 1.57 minutes. Total time spent at pharmacy: 2.98.
# 56.35: Customer#88 arrived at the pharmacy.
# 56.35: Customer#88 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 56.39: Customer#89 arrived at the pharmacy.
# 56.39: Customer#89 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 56.58: Customer#87 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 2.40 minutes. Total time spent at pharmacy: 2.40.
# 56.74: Customer#90 arrived at the pharmacy.
# 56.74: Customer#90 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.00 minutes.
# 56.93: Customer#91 arrived at the pharmacy.
# 56.98: Customer#92 arrived at the pharmacy.
# 57.48: Customer#93 arrived at the pharmacy.
# 57.95: Customer#89 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.55 minutes. Total time spent at pharmacy: 1.55.
# 57.95: Customer#91 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 1.02 minutes.
# 58.21: Customer#94 arrived at the pharmacy.
# 58.36: Customer#88 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 2.01 minutes. Total time spent at pharmacy: 2.01.
# 58.36: Customer#92 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 1.37 minutes.
# 58.55: Customer#95 arrived at the pharmacy.
# 58.86: Customer#90 received Medicine#3 and left. Queue wait time: 0.00 minutes. Service time: 2.13 minutes. Total time spent at pharmacy: 2.13.
# 58.86: Customer#93 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 1.39 minutes.
# 58.96: Customer#96 arrived at the pharmacy.
# 58.96: Customer#97 arrived at the pharmacy.
# 59.82: Customer#91 received Medicine#3 and left. Queue wait time: 1.02 minutes. Service time: 1.88 minutes. Total time spent at pharmacy: 2.90.
# 59.82: Customer#94 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 1.61 minutes.
# 60.34: Customer#93 received Medicine#1 and left. Queue wait time: 1.39 minutes. Service time: 1.48 minutes. Total time spent at pharmacy: 2.86.
# 60.34: Customer#95 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 1.79 minutes.
# 60.79: Customer#92 received Medicine#3 and left. Queue wait time: 1.37 minutes. Service time: 2.44 minutes. Total time spent at pharmacy: 3.81.
# 60.79: Customer#96 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 1.84 minutes.
# 61.47: Customer#94 received Medicine#2 and left. Queue wait time: 1.61 minutes. Service time: 1.65 minutes. Total time spent at pharmacy: 3.26.
# 61.47: Customer#97 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 2.51 minutes.
# 61.96: Customer#95 received Medicine#2 and left. Queue wait time: 1.79 minutes. Service time: 1.62 minutes. Total time spent at pharmacy: 3.41.
# 61.97: Customer#96 received Medicine#1 and left. Queue wait time: 1.84 minutes. Service time: 1.17 minutes. Total time spent at pharmacy: 3.01.
# 62.66: Customer#98 arrived at the pharmacy.
# 62.66: Customer#98 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 63.13: Customer#99 arrived at the pharmacy.
# 63.13: Customer#99 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 0.00 minutes.
# 63.47: Customer#97 received Medicine#3 and left. Queue wait time: 2.51 minutes. Service time: 1.99 minutes. Total time spent at pharmacy: 4.50.
# 64.55: Customer#100 arrived at the pharmacy.
# 64.55: Customer#100 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 0.00 minutes.
# 64.63: Customer#98 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.97 minutes. Total time spent at pharmacy: 1.97.
# 64.77: Customer#101 arrived at the pharmacy.
# 64.77: Customer#101 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.00 minutes.
# 64.96: Customer#99 received Medicine#2 and left. Queue wait time: 0.00 minutes. Service time: 1.82 minutes. Total time spent at pharmacy: 1.82.
# 65.58: Customer#102 arrived at the pharmacy.
# 65.58: Customer#102 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.00 minutes.
# 65.96: Customer#101 received Medicine#3 and left. Queue wait time: 0.00 minutes. Service time: 1.19 minutes. Total time spent at pharmacy: 1.19.
# 66.09: Customer#103 arrived at the pharmacy.
# 66.09: Customer#103 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.00 minutes.
# 66.25: Customer#100 received Medicine#2 and left. Queue wait time: 0.00 minutes. Service time: 1.70 minutes. Total time spent at pharmacy: 1.70.
# 66.32: Customer#104 arrived at the pharmacy.
# 66.32: Customer#104 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 66.53: Customer#105 arrived at the pharmacy.
# 67.06: Customer#106 arrived at the pharmacy.
# 67.19: Customer#102 received Medicine#3 and left. Queue wait time: 0.00 minutes. Service time: 1.61 minutes. Total time spent at pharmacy: 1.61.
# 67.19: Customer#105 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.66 minutes.
# 67.22: Customer#107 arrived at the pharmacy.
# 67.73: Customer#103 received Medicine#3 and left. Queue wait time: 0.00 minutes. Service time: 1.64 minutes. Total time spent at pharmacy: 1.64.
# 67.73: Customer#106 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.66 minutes.
# 67.76: Customer#104 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.43 minutes. Total time spent at pharmacy: 1.43.
# 67.76: Customer#107 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.53 minutes.
# 67.89: Customer#108 arrived at the pharmacy.
# 68.09: Customer#109 arrived at the pharmacy.
# 68.15: Customer#110 arrived at the pharmacy.
# 68.18: Customer#111 arrived at the pharmacy.
# 68.86: Customer#112 arrived at the pharmacy.
# 68.93: Customer#105 received Medicine#3 and left. Queue wait time: 0.66 minutes. Service time: 1.74 minutes. Total time spent at pharmacy: 2.40.
# 68.93: Customer#108 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 1.03 minutes.
# 69.24: Customer#113 arrived at the pharmacy.
# 69.25: Customer#114 arrived at the pharmacy.
# 69.79: Customer#106 received Medicine#3 and left. Queue wait time: 0.66 minutes. Service time: 2.06 minutes. Total time spent at pharmacy: 2.72.
# 69.79: Customer#109 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 1.70 minutes.
# 70.81: Customer#115 arrived at the pharmacy.
# 70.85: Customer#108 received Medicine#2 and left. Queue wait time: 1.03 minutes. Service time: 1.92 minutes. Total time spent at pharmacy: 2.95.
# 70.85: Customer#110 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.70 minutes.
# 70.96: Customer#107 received Medicine#3 and left. Queue wait time: 0.53 minutes. Service time: 3.21 minutes. Total time spent at pharmacy: 3.74.
# 70.96: Customer#111 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 2.78 minutes.
# 71.40: Customer#116 arrived at the pharmacy.
# 71.42: Customer#117 arrived at the pharmacy.
# 71.76: Customer#109 received Medicine#1 and left. Queue wait time: 1.70 minutes. Service time: 1.97 minutes. Total time spent at pharmacy: 3.67.
# 71.76: Customer#112 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 2.90 minutes.
# 71.99: Customer#111 received Medicine#1 and left. Queue wait time: 2.78 minutes. Service time: 1.02 minutes. Total time spent at pharmacy: 3.81.
# 71.99: Customer#113 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 2.74 minutes.
# 72.63: Customer#110 received Medicine#2 and left. Queue wait time: 2.70 minutes. Service time: 1.78 minutes. Total time spent at pharmacy: 4.48.
# 72.63: Customer#114 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 3.38 minutes.
# 72.95: Customer#118 arrived at the pharmacy.
# 73.56: Customer#112 received Medicine#3 and left. Queue wait time: 2.90 minutes. Service time: 1.81 minutes. Total time spent at pharmacy: 4.71.
# 73.56: Customer#115 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.75 minutes.
# 73.68: Customer#119 arrived at the pharmacy.
# 73.84: Customer#113 received Medicine#3 and left. Queue wait time: 2.74 minutes. Service time: 1.86 minutes. Total time spent at pharmacy: 4.60.
# 73.84: Customer#116 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 2.45 minutes.
# 75.12: Customer#120 arrived at the pharmacy.
# 75.28: Customer#115 received Medicine#2 and left. Queue wait time: 2.75 minutes. Service time: 1.72 minutes. Total time spent at pharmacy: 4.47.
# 75.28: Customer#117 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 3.86 minutes.
# 75.84: Customer#116 received Medicine#1 and left. Queue wait time: 2.45 minutes. Service time: 1.99 minutes. Total time spent at pharmacy: 4.44.
# 75.84: Customer#118 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 2.89 minutes.
# 76.04: Customer#121 arrived at the pharmacy.
# 76.44: Customer#114 received Medicine#3 and left. Queue wait time: 3.38 minutes. Service time: 3.82 minutes. Total time spent at pharmacy: 7.19.
# 76.44: Customer#119 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 2.76 minutes.
# 77.09: Customer#117 received Medicine#1 and left. Queue wait time: 3.86 minutes. Service time: 1.80 minutes. Total time spent at pharmacy: 5.66.
# 77.09: Customer#120 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 1.96 minutes.
# 77.12: Customer#118 received Medicine#1 and left. Queue wait time: 2.89 minutes. Service time: 1.28 minutes. Total time spent at pharmacy: 4.17.
# 77.12: Customer#121 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 1.08 minutes.
# 77.38: Customer#122 arrived at the pharmacy.
# 78.80: Customer#123 arrived at the pharmacy.
# 79.01: Customer#119 received Medicine#3 and left. Queue wait time: 2.76 minutes. Service time: 2.57 minutes. Total time spent at pharmacy: 5.33.
# 79.01: Customer#122 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 1.63 minutes.
# 79.37: Customer#120 received Medicine#3 and left. Queue wait time: 1.96 minutes. Service time: 2.28 minutes. Total time spent at pharmacy: 4.25.
# 79.37: Customer#123 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.57 minutes.
# 79.43: Customer#121 received Medicine#1 and left. Queue wait time: 1.08 minutes. Service time: 2.31 minutes. Total time spent at pharmacy: 3.39.
# 80.40: Customer#122 received Medicine#1 and left. Queue wait time: 1.63 minutes. Service time: 1.39 minutes. Total time spent at pharmacy: 3.02.
# 80.52: Customer#124 arrived at the pharmacy.
# 80.52: Customer#124 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 0.00 minutes.
# 81.60: Customer#125 arrived at the pharmacy.
# 81.60: Customer#125 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 81.72: Customer#124 received Medicine#2 and left. Queue wait time: 0.00 minutes. Service time: 1.20 minutes. Total time spent at pharmacy: 1.20.
# 81.81: Customer#126 arrived at the pharmacy.
# 81.81: Customer#126 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 82.13: Customer#127 arrived at the pharmacy.
# 82.14: Customer#123 received Medicine#3 and left. Queue wait time: 0.57 minutes. Service time: 2.78 minutes. Total time spent at pharmacy: 3.35.
# 82.14: Customer#127 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 0.01 minutes.
# 82.30: Customer#128 arrived at the pharmacy.
# 82.58: Customer#129 arrived at the pharmacy.
# 82.75: Customer#130 arrived at the pharmacy.
# 83.02: Customer#131 arrived at the pharmacy.
# 83.31: Customer#132 arrived at the pharmacy.
# 83.50: Customer#127 received Medicine#2 and left. Queue wait time: 0.01 minutes. Service time: 1.35 minutes. Total time spent at pharmacy: 1.37.
# 83.50: Customer#128 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 1.20 minutes.
# 83.77: Customer#125 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 2.17 minutes. Total time spent at pharmacy: 2.17.
# 83.77: Customer#129 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 1.19 minutes.
# 85.04: Customer#128 received Medicine#2 and left. Queue wait time: 1.20 minutes. Service time: 1.54 minutes. Total time spent at pharmacy: 2.74.
# 85.04: Customer#130 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.28 minutes.
# 85.32: Customer#126 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 3.52 minutes. Total time spent at pharmacy: 3.52.
# 85.32: Customer#131 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.31 minutes.
# 85.65: Customer#129 received Medicine#1 and left. Queue wait time: 1.19 minutes. Service time: 1.88 minutes. Total time spent at pharmacy: 3.07.
# 85.65: Customer#132 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 2.35 minutes.
# 85.95: Customer#133 arrived at the pharmacy.
# 86.04: Customer#134 arrived at the pharmacy.
# 86.47: Customer#131 received Medicine#2 and left. Queue wait time: 2.31 minutes. Service time: 1.14 minutes. Total time spent at pharmacy: 3.45.
# 86.47: Customer#133 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.51 minutes.
# 86.60: Customer#130 received Medicine#2 and left. Queue wait time: 2.28 minutes. Service time: 1.57 minutes. Total time spent at pharmacy: 3.85.
# 86.60: Customer#134 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.57 minutes.
# 86.61: Customer#135 arrived at the pharmacy.
# 86.69: Customer#136 arrived at the pharmacy.
# 87.51: Customer#132 received Medicine#3 and left. Queue wait time: 2.35 minutes. Service time: 1.86 minutes. Total time spent at pharmacy: 4.21.
# 87.51: Customer#135 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.90 minutes.
# 87.72: Customer#137 arrived at the pharmacy.
# 87.79: Customer#133 received Medicine#1 and left. Queue wait time: 0.51 minutes. Service time: 1.32 minutes. Total time spent at pharmacy: 1.84.
# 87.79: Customer#136 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 1.10 minutes.
# 87.80: Customer#138 arrived at the pharmacy.
# 88.00: Customer#139 arrived at the pharmacy.
# 88.49: Customer#140 arrived at the pharmacy.
# 88.70: Customer#134 received Medicine#1 and left. Queue wait time: 0.57 minutes. Service time: 2.10 minutes. Total time spent at pharmacy: 2.67.
# 88.70: Customer#137 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.98 minutes.
# 88.89: Customer#135 received Medicine#1 and left. Queue wait time: 0.90 minutes. Service time: 1.38 minutes. Total time spent at pharmacy: 2.28.
# 88.89: Customer#138 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 1.09 minutes.
# 89.33: Customer#141 arrived at the pharmacy.
# 89.48: Customer#142 arrived at the pharmacy.
# 90.14: Customer#137 received Medicine#3 and left. Queue wait time: 0.98 minutes. Service time: 1.44 minutes. Total time spent at pharmacy: 2.42.
# 90.14: Customer#139 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 2.14 minutes.
# 90.55: Customer#138 received Medicine#1 and left. Queue wait time: 1.09 minutes. Service time: 1.65 minutes. Total time spent at pharmacy: 2.75.
# 90.55: Customer#140 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 2.06 minutes.
# 90.69: Customer#136 received Medicine#3 and left. Queue wait time: 1.10 minutes. Service time: 2.90 minutes. Total time spent at pharmacy: 4.00.
# 90.69: Customer#141 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 1.36 minutes.
# 91.17: Customer#143 arrived at the pharmacy.
# 91.81: Customer#140 received Medicine#3 and left. Queue wait time: 2.06 minutes. Service time: 1.26 minutes. Total time spent at pharmacy: 3.32.
# 91.81: Customer#142 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 2.33 minutes.
# 92.43: Customer#144 arrived at the pharmacy.
# 92.47: Customer#139 received Medicine#1 and left. Queue wait time: 2.14 minutes. Service time: 2.33 minutes. Total time spent at pharmacy: 4.47.
# 92.47: Customer#143 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 1.30 minutes.
# 92.64: Customer#141 received Medicine#3 and left. Queue wait time: 1.36 minutes. Service time: 1.95 minutes. Total time spent at pharmacy: 3.31.
# 92.64: Customer#144 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 0.22 minutes.
# 92.90: Customer#145 arrived at the pharmacy.
# 93.24: Customer#146 arrived at the pharmacy.
# 93.38: Customer#147 arrived at the pharmacy.
# 93.59: Customer#143 received Medicine#3 and left. Queue wait time: 1.30 minutes. Service time: 1.12 minutes. Total time spent at pharmacy: 2.42.
# 93.59: Customer#145 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 0.70 minutes.
# 94.14: Customer#148 arrived at the pharmacy.
# 94.51: Customer#142 received Medicine#3 and left. Queue wait time: 2.33 minutes. Service time: 2.70 minutes. Total time spent at pharmacy: 5.02.
# 94.51: Customer#146 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 1.26 minutes.
# 94.57: Customer#144 received Medicine#2 and left. Queue wait time: 0.22 minutes. Service time: 1.93 minutes. Total time spent at pharmacy: 2.14.
# 94.57: Customer#147 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 1.19 minutes.
# 94.70: Customer#149 arrived at the pharmacy.
# 94.94: Customer#150 arrived at the pharmacy.
# 95.56: Customer#151 arrived at the pharmacy.
# 95.56: Customer#145 received Medicine#2 and left. Queue wait time: 0.70 minutes. Service time: 1.97 minutes. Total time spent at pharmacy: 2.66.
# 95.56: Customer#148 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 1.43 minutes.
# 95.83: Customer#147 received Medicine#2 and left. Queue wait time: 1.19 minutes. Service time: 1.26 minutes. Total time spent at pharmacy: 2.44.
# 95.83: Customer#149 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 1.13 minutes.
# 95.95: Customer#152 arrived at the pharmacy.
# 96.79: Customer#148 received Medicine#3 and left. Queue wait time: 1.43 minutes. Service time: 1.23 minutes. Total time spent at pharmacy: 2.65.
# 96.79: Customer#150 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 1.85 minutes.
# 96.81: Customer#146 received Medicine#1 and left. Queue wait time: 1.26 minutes. Service time: 2.30 minutes. Total time spent at pharmacy: 3.57.
# 96.81: Customer#151 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 1.25 minutes.
# 97.00: Customer#153 arrived at the pharmacy.
# 97.13: Customer#154 arrived at the pharmacy.
# 97.86: Customer#155 arrived at the pharmacy.
# 97.96: Customer#149 received Medicine#1 and left. Queue wait time: 1.13 minutes. Service time: 2.13 minutes. Total time spent at pharmacy: 3.26.
# 97.96: Customer#152 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.01 minutes.
# 98.77: Customer#151 received Medicine#2 and left. Queue wait time: 1.25 minutes. Service time: 1.96 minutes. Total time spent at pharmacy: 3.21.
# 98.77: Customer#153 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 1.77 minutes.
# 98.78: Customer#150 received Medicine#3 and left. Queue wait time: 1.85 minutes. Service time: 1.99 minutes. Total time spent at pharmacy: 3.84.
# 98.78: Customer#154 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 1.65 minutes.
# 98.99: Customer#156 arrived at the pharmacy.
# 99.24: Customer#157 arrived at the pharmacy.
# 99.26: Customer#158 arrived at the pharmacy.
# 99.89: Customer#159 arrived at the pharmacy.
# 99.98: Customer#152 received Medicine#2 and left. Queue wait time: 2.01 minutes. Service time: 2.02 minutes. Total time spent at pharmacy: 4.03.
# 99.98: Customer#155 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 2.12 minutes.
# 100.24: Customer#160 arrived at the pharmacy.
# 100.26: Customer#153 received Medicine#3 and left. Queue wait time: 1.77 minutes. Service time: 1.49 minutes. Total time spent at pharmacy: 3.25.
# 100.26: Customer#156 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 1.27 minutes.
# 100.74: Customer#154 received Medicine#3 and left. Queue wait time: 1.65 minutes. Service time: 1.95 minutes. Total time spent at pharmacy: 3.61.
# 100.74: Customer#157 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 1.49 minutes.
# 101.09: Customer#161 arrived at the pharmacy.
# 101.27: Customer#162 arrived at the pharmacy.
# 101.73: Customer#156 received Medicine#3 and left. Queue wait time: 1.27 minutes. Service time: 1.47 minutes. Total time spent at pharmacy: 2.74.
# 101.73: Customer#158 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.47 minutes.
# 101.97: Customer#155 received Medicine#1 and left. Queue wait time: 2.12 minutes. Service time: 1.99 minutes. Total time spent at pharmacy: 4.11.
# 101.97: Customer#159 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.08 minutes.
# 102.76: Customer#163 arrived at the pharmacy.
# 103.24: Customer#159 received Medicine#2 and left. Queue wait time: 2.08 minutes. Service time: 1.27 minutes. Total time spent at pharmacy: 3.36.
# 103.24: Customer#160 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 3.00 minutes.
# 103.77: Customer#164 arrived at the pharmacy.
# 103.83: Customer#158 received Medicine#2 and left. Queue wait time: 2.47 minutes. Service time: 2.10 minutes. Total time spent at pharmacy: 4.57.
# 103.83: Customer#161 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.74 minutes.
# ...
# 374.35: Customer#558 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 4.23 minutes.
# 374.96: Customer#556 received Medicine#2 and left. Queue wait time: 5.09 minutes. Service time: 1.71 minutes. Total time spent at pharmacy: 6.80.
# 374.96: Customer#559 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 4.64 minutes.
# 375.55: Customer#557 received Medicine#1 and left. Queue wait time: 3.85 minutes. Service time: 2.04 minutes. Total time spent at pharmacy: 5.89.
# 375.55: Customer#560 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 5.17 minutes.
# 375.87: Customer#558 received Medicine#3 and left. Queue wait time: 4.23 minutes. Service time: 1.52 minutes. Total time spent at pharmacy: 5.75.
# 375.87: Customer#561 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 4.96 minutes.
# 376.32: Customer#569 arrived at the pharmacy.
# 376.83: Customer#559 received Medicine#2 and left. Queue wait time: 4.64 minutes. Service time: 1.87 minutes. Total time spent at pharmacy: 6.51.
# 376.83: Customer#562 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 5.66 minutes.
# 377.07: Customer#570 arrived at the pharmacy.
# 377.12: Customer#571 arrived at the pharmacy.
# 377.29: Customer#560 received Medicine#1 and left. Queue wait time: 5.17 minutes. Service time: 1.74 minutes. Total time spent at pharmacy: 6.91.
# 377.29: Customer#563 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 5.51 minutes.
# 377.42: Customer#572 arrived at the pharmacy.
# 378.04: Customer#573 arrived at the pharmacy.
# 378.35: Customer#574 arrived at the pharmacy.
# 378.45: Customer#575 arrived at the pharmacy.
# 378.45: Customer#561 received Medicine#1 and left. Queue wait time: 4.96 minutes. Service time: 2.59 minutes. Total time spent at pharmacy: 7.55.
# 378.45: Customer#564 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 6.28 minutes.
# 378.80: Customer#562 received Medicine#2 and left. Queue wait time: 5.66 minutes. Service time: 1.97 minutes. Total time spent at pharmacy: 7.63.
# 378.80: Customer#565 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 5.26 minutes.
# 379.15: Customer#576 arrived at the pharmacy.
# 379.16: Customer#577 arrived at the pharmacy.
# 379.31: Customer#563 received Medicine#3 and left. Queue wait time: 5.51 minutes. Service time: 2.02 minutes. Total time spent at pharmacy: 7.52.
# 379.31: Customer#566 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 5.56 minutes.
# 379.49: Customer#578 arrived at the pharmacy.
# 380.06: Customer#564 received Medicine#3 and left. Queue wait time: 6.28 minutes. Service time: 1.61 minutes. Total time spent at pharmacy: 7.89.
# 380.06: Customer#567 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 6.26 minutes.
# 380.22: Customer#568 left after their patience ran out. Queue wait time: 5.94 minutes.
# 380.37: Customer#565 received Medicine#2 and left. Queue wait time: 5.26 minutes. Service time: 1.57 minutes. Total time spent at pharmacy: 6.84.
# 380.37: Customer#569 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 4.05 minutes.
# 380.48: Customer#579 arrived at the pharmacy.
# 380.91: Customer#566 received Medicine#1 and left. Queue wait time: 5.56 minutes. Service time: 1.60 minutes. Total time spent at pharmacy: 7.16.
# 380.91: Customer#570 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 3.83 minutes.
# 381.98: Customer#569 received Medicine#3 and left. Queue wait time: 4.05 minutes. Service time: 1.61 minutes. Total time spent at pharmacy: 5.66.
# 381.98: Customer#571 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 4.86 minutes.
# 382.11: Customer#567 received Medicine#2 and left. Queue wait time: 6.26 minutes. Service time: 2.05 minutes. Total time spent at pharmacy: 8.31.
# 382.11: Customer#572 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 4.70 minutes.
# 382.89: Customer#570 received Medicine#1 and left. Queue wait time: 3.83 minutes. Service time: 1.99 minutes. Total time spent at pharmacy: 5.82.
# 382.89: Customer#573 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 4.86 minutes.
# 384.23: Customer#580 arrived at the pharmacy.
# 384.38: Customer#581 arrived at the pharmacy.
# 384.48: Customer#572 received Medicine#1 and left. Queue wait time: 4.70 minutes. Service time: 2.37 minutes. Total time spent at pharmacy: 7.06.
# 384.48: Customer#574 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 6.13 minutes.
# 384.55: Customer#573 received Medicine#2 and left. Queue wait time: 4.86 minutes. Service time: 1.65 minutes. Total time spent at pharmacy: 6.51.
# 384.55: Customer#575 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 6.10 minutes.
# 384.78: Customer#582 arrived at the pharmacy.
# 385.30: Customer#576 left after their patience ran out. Queue wait time: 6.16 minutes.
# 385.37: Customer#571 received Medicine#2 and left. Queue wait time: 4.86 minutes. Service time: 3.40 minutes. Total time spent at pharmacy: 8.25.
# 385.37: Customer#577 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 6.21 minutes.
# 386.16: Customer#575 received Medicine#2 and left. Queue wait time: 6.10 minutes. Service time: 1.61 minutes. Total time spent at pharmacy: 7.71.
# 386.16: Customer#578 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 6.67 minutes.
# 386.36: Customer#577 received Medicine#3 and left. Queue wait time: 6.21 minutes. Service time: 0.99 minutes. Total time spent at pharmacy: 7.20.
# 386.36: Customer#579 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 5.88 minutes.
# 387.09: Customer#574 received Medicine#3 and left. Queue wait time: 6.13 minutes. Service time: 2.61 minutes. Total time spent at pharmacy: 8.74.
# 387.09: Customer#580 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.86 minutes.
# 387.40: Customer#579 received Medicine#1 and left. Queue wait time: 5.88 minutes. Service time: 1.04 minutes. Total time spent at pharmacy: 6.92.
# 387.40: Customer#581 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 3.02 minutes.
# 387.51: Customer#578 received Medicine#2 and left. Queue wait time: 6.67 minutes. Service time: 1.35 minutes. Total time spent at pharmacy: 8.02.
# 387.51: Customer#582 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 2.73 minutes.
# 388.71: Customer#583 arrived at the pharmacy.
# 388.73: Customer#580 received Medicine#2 and left. Queue wait time: 2.86 minutes. Service time: 1.64 minutes. Total time spent at pharmacy: 4.50.
# 388.73: Customer#583 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 0.02 minutes.
# 389.23: Customer#581 received Medicine#1 and left. Queue wait time: 3.02 minutes. Service time: 1.83 minutes. Total time spent at pharmacy: 4.86.
# 389.45: Customer#584 arrived at the pharmacy.
# 389.45: Customer#584 reserved 1 unit of Medicine#3 after reaching the counter. Queue waiting time: 0.00 minutes.
# 389.45: LAST unit of Medicine#3 reserved by Customer#584. No more can be reserved!
# 389.97: Customer#585 arrived at the pharmacy.
# 390.52: Customer#582 received Medicine#2 and left. Queue wait time: 2.73 minutes. Service time: 3.01 minutes. Total time spent at pharmacy: 5.74.
# 390.52: Customer#585 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.55 minutes.
# 390.74: Customer#583 received Medicine#2 and left. Queue wait time: 0.02 minutes. Service time: 2.01 minutes. Total time spent at pharmacy: 2.03.
# 390.93: Customer#586 arrived at the pharmacy.
# 390.93: Customer#586 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 0.00 minutes.
# 391.15: Customer#584 received Medicine#3 and left. Queue wait time: 0.00 minutes. Service time: 1.71 minutes. Total time spent at pharmacy: 1.71.
# 391.40: Customer#587 arrived at the pharmacy.
# 391.40: Customer#587 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 391.86: Customer#586 received Medicine#2 and left. Queue wait time: 0.00 minutes. Service time: 0.94 minutes. Total time spent at pharmacy: 0.94.
# 392.45: Customer#588 arrived at the pharmacy.
# 392.45: Customer#588 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 0.00 minutes.
# 392.46: Customer#589 arrived at the pharmacy.
# 392.86: Customer#585 received Medicine#1 and left. Queue wait time: 0.55 minutes. Service time: 2.34 minutes. Total time spent at pharmacy: 2.89.
# 392.86: Customer#589 reserved 1 unit of Medicine#2 after reaching the counter. Queue waiting time: 0.39 minutes.
# 392.86: LAST unit of Medicine#2 reserved by Customer#589. No more can be reserved!
# 392.88: Customer#590 arrived at the pharmacy.
# 393.35: Customer#587 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.96 minutes. Total time spent at pharmacy: 1.96.
# 393.35: Customer#590 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.47 minutes.
# 394.02: Customer#589 received Medicine#2 and left. Queue wait time: 0.39 minutes. Service time: 1.17 minutes. Total time spent at pharmacy: 1.56.
# 394.74: Customer#588 received Medicine#2 and left. Queue wait time: 0.00 minutes. Service time: 2.30 minutes. Total time spent at pharmacy: 2.30.
# 395.92: Customer#590 received Medicine#1 and left. Queue wait time: 0.47 minutes. Service time: 2.57 minutes. Total time spent at pharmacy: 3.04.
# 396.21: Customer#591 arrived at the pharmacy.
# 396.21: Customer#591 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 396.30: Customer#592 arrived at the pharmacy.
# 396.30: Customer#592 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 397.47: Customer#593 arrived at the pharmacy.
# 397.47: Customer#593 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 397.91: Customer#592 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.61 minutes. Total time spent at pharmacy: 1.61.
# 398.22: Customer#591 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 2.02 minutes. Total time spent at pharmacy: 2.02.
# 399.67: Customer#593 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 2.20 minutes. Total time spent at pharmacy: 2.20.
# 400.05: Customer#594 arrived at the pharmacy.
# 400.05: Customer#594 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 403.18: Customer#595 arrived at the pharmacy.
# 403.18: Customer#595 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 403.65: Customer#594 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 3.60 minutes. Total time spent at pharmacy: 3.60.
# 405.10: Customer#595 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.92 minutes. Total time spent at pharmacy: 1.92.
# 406.56: Customer#596 arrived at the pharmacy.
# 406.56: Customer#596 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 406.83: Customer#597 arrived at the pharmacy.
# 406.83: Customer#597 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 408.41: Customer#597 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.59 minutes. Total time spent at pharmacy: 1.59.
# 408.53: Customer#596 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.96 minutes. Total time spent at pharmacy: 1.96.
# 411.02: Customer#598 arrived at the pharmacy.
# 411.02: Customer#598 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 412.43: Customer#598 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.41 minutes. Total time spent at pharmacy: 1.41.
# 414.12: Customer#599 arrived at the pharmacy.
# 414.12: Customer#599 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 415.07: Customer#600 arrived at the pharmacy.
# 415.07: Customer#600 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 415.72: Customer#601 arrived at the pharmacy.
# 415.72: Customer#601 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 416.45: Customer#599 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 2.34 minutes. Total time spent at pharmacy: 2.34.
# 416.48: Customer#600 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.41 minutes. Total time spent at pharmacy: 1.41.
# 417.31: Customer#602 arrived at the pharmacy.
# 417.31: Customer#602 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 417.59: Customer#601 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.86 minutes. Total time spent at pharmacy: 1.86.
# 418.68: Customer#603 arrived at the pharmacy.
# 418.68: Customer#603 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 418.89: Customer#602 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.58 minutes. Total time spent at pharmacy: 1.58.
# 420.79: Customer#603 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 2.10 minutes. Total time spent at pharmacy: 2.10.
# 421.04: Customer#604 arrived at the pharmacy.
# 421.04: Customer#604 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 421.20: Customer#605 arrived at the pharmacy.
# 421.20: Customer#605 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 422.67: Customer#606 arrived at the pharmacy.
# 422.67: Customer#606 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 423.05: Customer#604 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 2.01 minutes. Total time spent at pharmacy: 2.01.
# 423.68: Customer#605 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 2.49 minutes. Total time spent at pharmacy: 2.49.
# 424.24: Customer#606 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.56 minutes. Total time spent at pharmacy: 1.56.
# 425.51: Customer#607 arrived at the pharmacy.
# 425.51: Customer#607 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 427.19: Customer#607 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.68 minutes. Total time spent at pharmacy: 1.68.
# 428.14: Customer#608 arrived at the pharmacy.
# 428.14: Customer#608 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 428.76: Customer#609 arrived at the pharmacy.
# 428.76: Customer#609 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 429.50: Customer#608 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.36 minutes. Total time spent at pharmacy: 1.36.
# 430.35: Customer#609 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 1.59 minutes. Total time spent at pharmacy: 1.59.
# 431.77: Customer#610 arrived at the pharmacy.
# 431.77: Customer#610 reserved 1 unit of Medicine#1 after reaching the counter. Queue waiting time: 0.00 minutes.
# 431.77: LAST unit of Medicine#1 reserved by Customer#610. No more can be reserved!
# 433.81: Customer#610 received Medicine#1 and left. Queue wait time: 0.00 minutes. Service time: 2.04 minutes. Total time spent at pharmacy: 2.04.

# %%
for medicine in medicines:
    print(medicine)
    if pharmacy.sold_out[medicine].triggered:
        sellout_time = pharmacy.sold_out_timestamp[medicine]
        num_renegers = pharmacy.num_renegers[medicine]
        print(f"Sold out {sellout_time:.2f} minutes after pharmacy opened.")
        print(f"{num_renegers} people had to abandon the queue and leave the pharmacy.")
    else:
        print(f"Remaining stock: {pharmacy.med_stock[medicine]} / {MED_STOCK}")

    print("-----------------------------------------------------------------")

print(f"\n{nr_impatient_leavers} people left the queue due to waiting too long.")
# Out:
# Medicine#1
# Sold out 431.77 minutes after pharmacy opened.
# 0 people had to abandon the queue and leave the pharmacy.
# -----------------------------------------------------------------
# Medicine#2
# Sold out 392.86 minutes after pharmacy opened.
# 0 people had to abandon the queue and leave the pharmacy.
# -----------------------------------------------------------------
# Medicine#3
# Sold out 389.45 minutes after pharmacy opened.
# 0 people had to abandon the queue and leave the pharmacy.
# -----------------------------------------------------------------
#
# 10 people left the queue due to waiting too long.

# %%
avg_q_time = sum(stats.q_wait_times) / len(stats.q_wait_times)
avg_s_time = sum(stats.s_wait_times) / len(stats.s_wait_times)

print(f"Average queue wait time: {avg_q_time:.2f} minutes")
print(f"Average service time: {avg_s_time:.2f} minutes")

max_q_time = max(stats.q_wait_times)
print(f"Maximum queue waiting time: {max_q_time:.2f} minutes")
# Out:
# Average queue wait time: 2.13 minutes
# Average service time: 1.89 minutes
# Maximum queue waiting time: 7.10 minutes

# %%
plt.hist(stats.q_wait_times, bins=10, linewidth=0.5, edgecolor="white")
plt.title("Queue time frequency")
plt.axvline(avg_q_time, alpha=0.5, c="black", ls="--")
plt.show()
